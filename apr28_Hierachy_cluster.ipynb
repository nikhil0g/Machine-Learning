# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
data = pd.read_csv('countrycluster.csv',index_col='Country')

# %%
data
# Out:
#            Latitude  Longitude Language
# Country
# USA           44.97    -103.77  English
# Canada        62.40     -96.80  English
# France        46.75       2.40   French
# UK            54.01      -2.53  English
# Germany       51.15      10.40   German
# Australia    -25.45     133.11  English

# %%
X_data = data.copy()

# %%
X_data
# Out:
#            Latitude  Longitude Language
# Country
# USA           44.97    -103.77  English
# Canada        62.40     -96.80  English
# France        46.75       2.40   French
# UK            54.01      -2.53  English
# Germany       51.15      10.40   German
# Australia    -25.45     133.11  English

# %%
X_data = X_data.drop(['Language'],axis=1)

# %%
X_data
# Out:
#            Latitude  Longitude
# Country
# USA           44.97    -103.77
# Canada        62.40     -96.80
# France        46.75       2.40
# UK            54.01      -2.53
# Germany       51.15      10.40
# Australia    -25.45     133.11

# %%
sns.clustermap(X_data)

# %% [markdown]
# # Agglomarative

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
X = iris.data

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
X.shape
# Out:
# (150, 4)

# %%
X = X[0:50,:]

# %%
X.shape
# Out:
# (50, 4)

# %%
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# ### The linkage distance threshold above which, clusters will not be merged.

# %%
model = AgglomerativeClustering(distance_threshold=1.5,n_clusters=None)

# %%
model.fit(X)
# Out:
# AgglomerativeClustering(distance_threshold=1.5, n_clusters=None)

# %%
model.fit_predict(X)
# Out:
# array([2, 0, 0, 0, 2, 1, 0, 2, 0, 0, 1, 0, 0, 0, 1, 1, 1, 2, 1, 2, 1, 2,
#        0, 2, 0, 0, 2, 2, 2, 0, 0, 1, 1, 1, 0, 0, 1, 2, 0, 2, 2, 0, 0, 2,
#        2, 0, 2, 0, 1, 2])

# %%
model.n_clusters_
# Out:
# 3

# %%
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster import hierarchy

# %%
Z = hierarchy.linkage(model.children_,'ward')
plt.figure(figsize=(20,10))
dn = hierarchy.dendrogram(Z)

# %%
identified_cluster = model.fit_predict(X)

# %%
identified_cluster
# Out:
# array([2, 0, 0, 0, 2, 1, 0, 2, 0, 0, 1, 0, 0, 0, 1, 1, 1, 2, 1, 2, 1, 2,
#        0, 2, 0, 0, 2, 2, 2, 0, 0, 1, 1, 1, 0, 0, 1, 2, 0, 2, 2, 0, 0, 2,
#        2, 0, 2, 0, 1, 2])

# %%
data = pd.DataFrame(X)

# %%
data
# Out:
#       0    1    2    3
# 0   5.1  3.5  1.4  0.2
# 1   4.9  3.0  1.4  0.2
# 2   4.7  3.2  1.3  0.2
# 3   4.6  3.1  1.5  0.2
# 4   5.0  3.6  1.4  0.2
# 5   5.4  3.9  1.7  0.4
# 6   4.6  3.4  1.4  0.3
# 7   5.0  3.4  1.5  0.2
# 8   4.4  2.9  1.4  0.2
# 9   4.9  3.1  1.5  0.1
# 10  5.4  3.7  1.5  0.2
# 11  4.8  3.4  1.6  0.2
# 12  4.8  3.0  1.4  0.1
# 13  4.3  3.0  1.1  0.1
# 14  5.8  4.0  1.2  0.2
# 15  5.7  4.4  1.5  0.4
# 16  5.4  3.9  1.3  0.4
# 17  5.1  3.5  1.4  0.3
# 18  5.7  3.8  1.7  0.3
# 19  5.1  3.8  1.5  0.3
# 20  5.4  3.4  1.7  0.2
# 21  5.1  3.7  1.5  0.4
# 22  4.6  3.6  1.0  0.2
# 23  5.1  3.3  1.7  0.5
# 24  4.8  3.4  1.9  0.2
# 25  5.0  3.0  1.6  0.2
# 26  5.0  3.4  1.6  0.4
# 27  5.2  3.5  1.5  0.2
# 28  5.2  3.4  1.4  0.2
# 29  4.7  3.2  1.6  0.2
# 30  4.8  3.1  1.6  0.2
# 31  5.4  3.4  1.5  0.4
# 32  5.2  4.1  1.5  0.1
# 33  5.5  4.2  1.4  0.2
# 34  4.9  3.1  1.5  0.2
# 35  5.0  3.2  1.2  0.2
# 36  5.5  3.5  1.3  0.2
# 37  4.9  3.6  1.4  0.1
# 38  4.4  3.0  1.3  0.2
# ...

# %%
data['Cluster'] = identified_cluster

# %%
data
# Out:
#       0    1    2    3  Cluster
# 0   5.1  3.5  1.4  0.2        2
# 1   4.9  3.0  1.4  0.2        0
# 2   4.7  3.2  1.3  0.2        0
# 3   4.6  3.1  1.5  0.2        0
# 4   5.0  3.6  1.4  0.2        2
# 5   5.4  3.9  1.7  0.4        1
# 6   4.6  3.4  1.4  0.3        0
# 7   5.0  3.4  1.5  0.2        2
# 8   4.4  2.9  1.4  0.2        0
# 9   4.9  3.1  1.5  0.1        0
# 10  5.4  3.7  1.5  0.2        1
# 11  4.8  3.4  1.6  0.2        0
# 12  4.8  3.0  1.4  0.1        0
# 13  4.3  3.0  1.1  0.1        0
# 14  5.8  4.0  1.2  0.2        1
# 15  5.7  4.4  1.5  0.4        1
# 16  5.4  3.9  1.3  0.4        1
# 17  5.1  3.5  1.4  0.3        2
# 18  5.7  3.8  1.7  0.3        1
# 19  5.1  3.8  1.5  0.3        2
# 20  5.4  3.4  1.7  0.2        1
# 21  5.1  3.7  1.5  0.4        2
# 22  4.6  3.6  1.0  0.2        0
# 23  5.1  3.3  1.7  0.5        2
# 24  4.8  3.4  1.9  0.2        0
# 25  5.0  3.0  1.6  0.2        0
# 26  5.0  3.4  1.6  0.4        2
# 27  5.2  3.5  1.5  0.2        2
# ...
